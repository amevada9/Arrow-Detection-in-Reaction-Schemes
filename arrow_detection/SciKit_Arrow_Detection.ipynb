# %% [markdown]
# # Using Scikit-Image to do Arrow Matching

# %% [markdown]
# ## This notebook is working on creating the arrow classifer for the reaction schemes

# %%
import os
import cv2
import math 
import imutils
import json
import copy
import time
import logging

import scipy
import numpy as np
from scipy import ndimage as ndi
import matplotlib.pyplot as plt
import pandas as pd

import pytesseract
from pytesseract import Output

import sklearn
from sklearn.cluster import KMeans

import skimage
from skimage import io
from skimage.util import pad
from skimage.color import rgb2gray
from skimage.measure import regionprops
from skimage.measure import find_contours
from skimage.util import crop as crop_skimage
from skimage.util import random_noise
from skimage.morphology import binary_closing, disk
from skimage.morphology import skeletonize as skeletonize_skimage

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import RMSprop

import sklearn
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

from arrow import *
from scikit_arrow_utils import arrow_average, arrow_centroid, line_mag, get_contour_height, get_contour_length, get_orientation
from image_utils import binary_close, binarize, binary_floodfill, skeletonize, pixel_ratio, skeletonize_area_ratio
from scikit_scripts import pad_image, segment_image, show_contours, get_image_contours
from detection import get_direction, pipeline

# %%
model = keras.models.load_model(os.path.join(os.getcwd(), 'models', 'notOverfittedModel2'))

# trainX, trainY = load_training_set()
# # testX, testY = load_testing_set()

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 498, 498, 16)      160
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 249, 249, 16)      0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 249, 249, 16)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 247, 247, 32)      4640
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 123, 123, 32)      0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 123, 123, 32)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 121, 121, 32)      9248
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 60, 60, 32)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 58, 58, 32)        9248
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 29, 29, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 27, 27, 32)        9248
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 11, 11, 32)        9248
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 5, 5, 32)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               205056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 247,105
# Trainable params: 247,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
def process_paper(model, path_to_images, document_name, save_in_json = True, verbose=1):
    reactions = sorted(os.listdir(os.path.join(os.getcwd(), path_to_images)))[1:]
    arrows = {}
    count = 0
    for i, image_name in enumerate(reactions):
        image = io.imread(os.path.join(path_to_images, image_name))
        try:
            info, cnts, averages, directions = pipeline(image,  image_name, count, model=model,verbose=verbose)
            count += 1
        except:
            print(image_name + ' had an Error')
            info = {}
            info['Status'] = 'Error Thrown'
            continue
        arrows[image_name] = info
    if save_in_json:
        with open(os.path.join(os.getcwd(), 'results', document_name + '_results.json'), 'w') as f:
            json.dump(arrows, f)
    return arrows

# %%
reactions1 = os.path.join(os.getcwd(), 'test_reaction_ims')

arrows = process_paper(model, 'test_reaction_ims', 'test_ims3')
# Out:
# Label 0 CroppedPage13-1.png 1 Arrows Extracted! Time Elapsed: 4.13s
# Label 1 CroppedPage15-1.png 1 Arrows Extracted! Time Elapsed: 4.67s
# Label 2 CroppedPage18-1.png 1 Arrows Extracted! Time Elapsed: 7.30s
# Label 3 CroppedPage19-1.png 1 Arrows Extracted! Time Elapsed: 2.93s
# Label 4 CroppedPage20-1.png 1 Arrows Extracted! Time Elapsed: 4.07s
# Label 5 CroppedPage21-1.png 1 Arrows Extracted! Time Elapsed: 3.07s
# Label 6 CroppedPage3-2.png 1 Arrows Extracted! Time Elapsed: 0.26s
# Label 7 CroppedPage33-1.png 1 Arrows Extracted! Time Elapsed: 0.31s
# Label 8 CroppedPage33-2.png 1 Arrows Extracted! Time Elapsed: 0.45s
# Label 113 ja5b11438_si_001Page9-2.png 2 Arrows Extracted! Time Elapsed: 1.84s
# Label 114 ja6b04029_si_003Page2-1.png: No Arrows were Identified
# Label 115 ja6b04029_si_003Page4-1.png 2 Arrows Extracted! Time Elapsed: 1.40s
# Label 116 ja6b04029_si_003Page4-2.png 1 Arrows Extracted! Time Elapsed: 1.72s
# Label 117 ja7b07685_si_001Page10-1.png 1 Arrows Extracted! Time Elapsed: 0.96s
# Label 118 ja7b07685_si_001Page9-1.png 1 Arrows Extracted! Time Elapsed: 1.12s
# Label 119 ja7b12570_si_005Page8-1.png 1 Arrows Extracted! Time Elapsed: 1.11s
# Label 120 ja7b12570_si_005Page9-1.png 1 Arrows Extracted! Time Elapsed: 1.92s
# Label 121 ja809542r_si_001Page3-3.png 1 Arrows Extracted! Time Elapsed: 1.15s
# Label 122 ja809542r_si_001Page4-1.png 1 Arrows Extracted! Time Elapsed: 1.51s
# Label 123 ja809542r_si_001Page4-2.png 1 Arrows Extracted! Time Elapsed: 1.13s
# Label 124 ja809542r_si_001Page5-1.png 1 Arrows Extracted! Time Elapsed: 1.29s
# Label 125 ja908194b_si_001Page10-1.png 1 Arrows Extracted! Time Elapsed: 8.49s
# Label 126 ja908194b_si_001Page12-1.png 1 Arrows Extracted! Time Elapsed: 6.69s
# Label 127 ja908194b_si_001Page14-1.png 1 Arrows Extracted! Time Elapsed: 3.65s
# Label 128 ja908194b_si_001Page9-1.png 1 Arrows Extracted! Time Elapsed: 4.99s
# Label 129 ja9b00391_si_001Page3-2.png 1 Arrows Extracted! Time Elapsed: 1.77s
# Label 130 ja9b00391_si_001Page4-1.png 1 Arrows Extracted! Time Elapsed: 4.88s
# Label 131 ja9b00391_si_001Page5-1.png: No Arrows were Identified
# Label 132 ja9b00391_si_001Page5-2.png 1 Arrows Extracted! Time Elapsed: 3.03s
# Label 133 ja9b00391_si_001Page6-1.png 1 Arrows Extracted! Time Elapsed: 2.97s
# Label 134 ja9b06830_si_001Page18-1.png 3 Arrows Extracted! Time Elapsed: 1.32s
# Label 135 ja9b06830_si_001Page19-1.png 1 Arrows Extracted! Time Elapsed: 1.13s
# Label 136 ja9b06830_si_001Page21-1.png 1 Arrows Extracted! Time Elapsed: 1.03s
# Label 137 ja9b07512_si_001Page10-1.png 8 Arrows Extracted! Time Elapsed: 5.75s
# ja9b07512_si_001Page11-1.png had an Error
# Label 138 ja9b07512_si_001Page12-1.png 1 Arrows Extracted! Time Elapsed: 2.36s
# ja9b07512_si_001Page13-1.png had an Error
# ja9b07512_si_001Page14-1.png had an Error

# %%
reactions1 = os.path.join(os.getcwd(), 'test_reaction_ims')
reactions = sorted(os.listdir(reactions1))[1:]
idx = reactions.index('ja9b07512_si_001Page14-1.png')
image = io.imread(os.path.join(reactions1, reactions[2]))
# image = binarize(image)
# image.shape
# seg_im = segment_image(image)
info, final_contours, averages, directions = pipeline(image, doc_name = '', count = 0)
# for i, item in enumerate(reactions):
#     print("Element " + str(i) + ': ' + item)
# Out:
# Label 0  1 Arrows Extracted! Time Elapsed: 7.28s

# %%
show_contours(image, final_contours, num = -1)
print(info)

# %%
get_contour_height(final_contours[0])
