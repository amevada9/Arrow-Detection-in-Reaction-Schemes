# %%
import numpy as np
import skimage
from skimage import io
from skimage.color import rgb2gray

# %%
arrows_jpg = io.imread('arrows.jpg')
io.imshow(arrows_jpg)

# %%
arrows_jpg.shape
# Out:
# (540, 490, 3)

# %%
arrows_gray = rgb2gray(arrows_jpg)
print(arrows_gray.shape)
io.imshow(arrows_gray)
# Out:
# (540, 490)
